# %% [markdown]
# # CD | Change Directory
# Se usa para cambiar el directorio actual de trabajo
#
#
# **Revisar:**
#   * [Rutas](../../notebooks/2-rutas.ipynb)
#   * [Operadores](../../notebooks/3-operadores.ipynb)

# %% [markdown]
# ## Sintaxis
# ```bash
# cd [ruta]
# ```
# > Solo cd te lleva a tu directorio home (`/home/useractual`)

# %%
# !cd && pwd
# Out:
# /home/user

# %% [markdown]
# ## Opciones

# %% [markdown]
# ### Sube un nivel

# %%
# !cd .. && ls
# Out:
# README.md  level-1

# %% [markdown]
# ### Sube dos niveles

# %%
# !cd ../../ && ls
# Out:
# LICENSE.md  commands  notebooks  requirements.txt
# README.md   files     path-bash  scripts

# %% [markdown]
# ### Ruta absoluta

# %%
# !cd ~/Documents/ && pwd
# Out:
# /home/user/Documents

# %% [markdown]
# ### Cambia al directorio anterior `-`
# Si estás es un directorio y vas otro puedes volver donde antes estabas trabajando

# %%
# !cd ~ && pwd && cd -
# Out:
# /home/user
# /home/user/Documents/bash-scripting/commands/level-1
