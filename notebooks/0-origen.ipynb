# %% [markdown]
# # BASH SCRIPTING
# Proceso de escribir un archivo de texto plano (un script) con una secuencia de comandos de Bash para que se ejecuten automáticamente, en lugar de introducirlos manualmente en la terminal.

# %%
# !echo "Hello World"
# Out:
# Hello World

# %% [markdown]
# > Comando `echo` permite mostrar un mensaje

# %% [markdown]
# ## Características
#   * Automatización
#   * Interacción con el sistema operativo
#   * Portabilidad (pueden usar en diferentes distribuciones Linux, macOs, Unix)
